# %%
import os
import sys
import pandas as pd
import csv

# %%
data = pd.read_csv('weibo_12features.csv')

# %%
data.describe()
# Out:
#          ﻿userid  original_weibo  repost_weibo   like_weibo       follow  \
# count  108.00000      108.000000    108.000000   108.000000   108.000000
# mean    54.50000     2229.712963    667.712963   794.814815   444.277778
# std     31.32092     1600.574389    786.448269   914.891119   311.704594
# min      1.00000      235.000000      1.000000     0.000000     2.000000
# 25%     27.75000     1057.000000    156.500000   180.250000   221.250000
# 50%     54.50000     1859.000000    402.000000   479.500000   385.000000
# 75%     81.25000     3064.750000    947.500000  1017.250000   585.750000
# max    108.00000     7648.000000   4167.000000  4443.000000  1815.000000
#
#                  fans   vip_level   av_comment       av_like  av_re_comment  \
# count      108.000000  108.000000   108.000000    108.000000     108.000000
# mean   1595585.194444   44.398148   468.490876    918.195564    2275.758155
# std    1574973.429179    6.130878   751.896677   2083.136134    4060.271324
# ...

# %%
data1 = pd.read_csv('total_21features.csv')
data1.describe()
# Out:
#        Unnamed: 0      userid  original_weibo  repost_weibo   like_weibo  \
# count   87.000000   87.000000       87.000000     87.000000    87.000000
# mean    43.000000   54.022989     2295.425287    724.367816   823.965517
# std     25.258662   31.316456     1564.143585    840.260579   923.867974
# min      0.000000    1.000000      235.000000      7.000000     9.000000
# 25%     21.500000   26.000000     1132.500000    183.000000   203.500000
# 50%     43.000000   52.000000     1915.000000    457.000000   546.000000
# 75%     64.500000   82.500000     3072.500000    948.000000  1023.500000
# max     86.000000  108.000000     7648.000000   4167.000000  4443.000000
#
#             follow            fans  vip_level   av_comment       av_like  \
# count    87.000000       87.000000  87.000000    87.000000     87.000000
# mean    423.517241  1534408.747126  44.528736   461.058611    953.670369
# std     275.190034  1559783.508560   5.408518   751.424832   2256.393840
# ...

# %%
tmp = pd.read_csv('features_lable_network1.csv')
tmp
# Out:
#     celebrity  userid  follow     fans  original_weibo  repost_weibo  \
# 0           0       1     316  3775598            2834           679
# 1           2       3     393  4348114            4082          1164
# 2           4       5     751   778999            4050          2285
# 3           5       6     334  1241240            1351           766
# 4           6       7     701  2498820            3772          1145
# 5           7       8     442  3270155            2457          1126
# 6           8       9     759  2295703            3605          1438
# 7           9      10     181  5733434            2199           211
# 8          11      12     475  3956210            1369           515
# 9          12      13     202  6738735            2025           477
# 10         13      14     802  2901026            2850           245
# 11         14      15     429   660991            3005           586
# 12         15      16     784  4966250            2120           408
# ...

# %%
tmp.columns
# Out:
# Index(['celebrity', 'userid', 'follow', 'fans', 'original_weibo',
#        'repost_weibo', 'like_weibo', 'av_comment', 'av_like', 'av_re_comment',
#        'av_re_like', 'av_re_repost', 'av_repost', 'product_num', 'ave_price',
#        'price_var', 'product_comm', 'product_comm_sent', 'update',
#        'neg_com_perc', 'turnover_month_appr', 'sales_month', 'credit',
#        'refund_rate', 'comment_num', 'com_perc', 'taobao_fans', 'label',
#        'count', 'count2', 'count3', 'count_sum', 'perc1', 'perc2', 'perc3',
#        'fans_trans', 'quchuhou_len'],
#       dtype='object')

# %%
data2 = tmp[[ 'refund_rate','com_perc']]
data2.describe()
# Out:
#        refund_rate   com_perc
# count    83.000000  83.000000
# mean      0.442771   0.993621
# std       0.202408   0.010134
# min       0.150000   0.924051
# 25%       0.315000   0.993487
# 50%       0.390000   0.996383
# 75%       0.495000   0.997769
# max       1.190000   1.000000

# %%
0.44
