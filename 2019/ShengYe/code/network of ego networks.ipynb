# %%
import os
import sys
import math
import numpy as np
import pandas as pd
import csv 
import matplotlib.pyplot as plt 
from matplotlib.ticker import MultipleLocator,FormatStrFormatter
% matplotlib inline

# %%
df1 = pd.read_csv('multi2_count.csv', encoding='utf8')

# %%
df2 = pd.read_csv('multi5_count.csv', encoding='utf8')

# %%
df3 = pd.read_csv('multi11_count.csv', encoding='utf8')

# %%
tmp = pd.merge(df1,df2,how='left',on = 'celebrity')
df_count = pd.merge(tmp,df3,how='left',on = 'celebrity')
df_count
# Out:
#      celebrity  count  count2  count3
# 0            0    152      74      76
# 1            1    200      94      65
# 2            2    260     108      69
# 3            3    542     180      77
# 4            4    331     164      95
# 5            5    131     115      51
# 6            6    417     172     112
# 7            7    299     148      77
# 8            8    156      34      35
# 9            9     59      31      23
# 10          10     34      24      19
# 11          11    362     180     113
# 12          12    189     119     102
# 13          13    180      90      73
# 14          14     89      32      35
# 15          15    183      98      80
# 16          16    214      90      75
# 17          17    680     224     166
# 18          18     81      36      36
# 19          19    728     251      94
# 20          20    196      65      37
# 21          21    126      54      47
# 22          22     83      40      17
# 23          23    110      44      22
# ...

# %%
df_count.to_csv('df_count.csv',index=False)
