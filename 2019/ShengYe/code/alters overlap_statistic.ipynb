# %%
import os
import sys
import math
import numpy as np
import pandas as pd
import csv 
import matplotlib.pyplot as plt 
from matplotlib.ticker import MultipleLocator,FormatStrFormatter
% matplotlib inline

# %%
result = pd.read_csv('overlap_result.csv',sep = '\s')
result = result.rename(columns={'name': 'weibo_id'}) 
result
# Out:
# c:\users\yee shen\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
#                                                                                                                                                                                                                                                                                                                                                      weibo_id  \
# ...

# %%
result.to_csv('overlap_result1.csv',encoding='utf-8')

# %%
result.describe()
# Out:
#              length
# count  56459.000000
# mean       1.336297
# std        1.579989
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max       69.000000

# %%
cele_list = pd.read_excel('电商网红名单.xlsx', encoding='utf-8-sig')
cele_list
# Out:
#      celebrity     weibo_id  \
# 0            0        ALU_U
# 1            1       Lin张林超
# 2            2  AM__FASHION
# 3            3       MALInv
# 4            4      Tikilee
# 5            5   yeswomen小宜
# 6            6         ZY喜哥
# 7            7    阿希哥VCRUAN
# 8            8  狼宝-LangBoom
# 9            9    林珊珊_Sunny
# 10          10          卢洁云
# 11          11      美美de夏夏啊
# 12          12        呛口小辣椒
# 13          13      小刘小粒赵大喜
# 14          14        小怡吖小怡
# 15          15     雪梨Cherie
# 16          16     于momo小饺子
# 17          17       张大奕eve
# 18          18       13c13c
# 19          19     onlyanna
# 20          20     _aaayuko
# 21          21      13_macy
# 22          22    A-bowlife
# 23          23      Alice赵静
# 24          24     ashui-AS
# 25          25      Ciny心霓儿
# 26          26       DALU大璐
# 27          27     DDshadow
# 28          28  delicious大金
# 29          29       D-nana
# ..         ...          ...
# 78          78   腻总ninitalk
# ...

# %%
merge = pd.merge(cele_list,result,how='left',on='weibo_id')
merge = merge[merge['length'].notnull()]
merge = merge.sort_values(['length'],ascending = False)
merge
# Out:
#      celebrity      weibo_id  \
# 17          17        张大奕eve
# 0            0         ALU_U
# 7            7     阿希哥VCRUAN
# 63          63           管阿姨
# 12          12         呛口小辣椒
# 18          18        13c13c
# 1            1        Lin张林超
# 56          56           茶茶丷
# 101        101        张佐佐997
# 74          74          林小宅-
# 11          11       美美de夏夏啊
# 6            6          ZY喜哥
# 105        105           周扬青
# 106        106           左岸潇
# 55          55           蔡珍妮
# 48          48      seina施依娜
# 15          15      雪梨Cherie
# 64          64      龟酱turtle
# 72          72      李雨桐Luyee
# 20          20      _aaayuko
# 65          65       韩雨嘉Yoga
# 41          41       MINI猪七七
# 83          83      唐颖Connie
# 67          67         狠赵狠蛇蛇
# 98          98           张予曦
# 9            9     林珊珊_Sunny
# 5            5    yeswomen小宜
# 4            4       Tikilee
# 34          34     FengFan_x
# 97          97      张思佳-SISI
# ..         ...           ...
# ...

# %%
df5 = pd.read_csv('ego_overlap.csv', encoding='utf-8-sig')
df5
# Out:
#      Unnamed: 0  celebrity      weibo_id  \
# 0             0         17        张大奕eve
# 1             1          0         ALU_U
# 2             2          7     阿希哥VCRUAN
# 3             3         63           管阿姨
# 4             4         12         呛口小辣椒
# 5             5         18        13c13c
# 6             6          1        Lin张林超
# 7             7         56           茶茶丷
# 8             8        101        张佐佐997
# 9             9         74          林小宅-
# 10           10         11       美美de夏夏啊
# 11           11          6          ZY喜哥
# 12           12        105           周扬青
# 13           13        106           左岸潇
# 14           14         55           蔡珍妮
# 15           15         48      seina施依娜
# 16           16         15      雪梨Cherie
# 17           17         64      龟酱turtle
# 18           18         72      李雨桐Luyee
# 19           19         20      _aaayuko
# 20           20         65       韩雨嘉Yoga
# 21           21         41       MINI猪七七
# ...

# %%
df5_new = df5[['celebrity','weibo_id','new_value_list','quchuhou_len']]
df5_new
# Out:
#      celebrity      weibo_id  \
# 0           17        张大奕eve
# 1            0         ALU_U
# 2            7     阿希哥VCRUAN
# 3           63           管阿姨
# 4           12         呛口小辣椒
# 5           18        13c13c
# 6            1        Lin张林超
# 7           56           茶茶丷
# 8          101        张佐佐997
# 9           74          林小宅-
# 10          11       美美de夏夏啊
# 11           6          ZY喜哥
# 12         105           周扬青
# 13         106           左岸潇
# 14          55           蔡珍妮
# 15          48      seina施依娜
# 16          15      雪梨Cherie
# 17          64      龟酱turtle
# 18          72      李雨桐Luyee
# 19          20      _aaayuko
# 20          65       韩雨嘉Yoga
# 21          41       MINI猪七七
# 22          83      唐颖Connie
# 23          67         狠赵狠蛇蛇
# 24          98           张予曦
# 25           9     林珊珊_Sunny
# 26           5    yeswomen小宜
# 27           4       Tikilee
# 28          34     FengFan_x
# 29          97      张思佳-SISI
# ..         ...           ...
# ...

# %%
df5_overlap = df5_new[df5_new['quchuhou_len']>0]
df5_overlap
# Out:
#      celebrity      weibo_id  \
# 0           17        张大奕eve
# 1            0         ALU_U
# 2            7     阿希哥VCRUAN
# 3           63           管阿姨
# 4           12         呛口小辣椒
# 5           18        13c13c
# 6            1        Lin张林超
# 7           56           茶茶丷
# 8          101        张佐佐997
# 9           74          林小宅-
# 10          11       美美de夏夏啊
# 11           6          ZY喜哥
# 12         105           周扬青
# 13         106           左岸潇
# 14          55           蔡珍妮
# 15          48      seina施依娜
# 16          15      雪梨Cherie
# 17          64      龟酱turtle
# 18          72      李雨桐Luyee
# 19          20      _aaayuko
# 20          65       韩雨嘉Yoga
# 21          41       MINI猪七七
# 22          83      唐颖Connie
# 23          67         狠赵狠蛇蛇
# 24          98           张予曦
# 25           9     林珊珊_Sunny
# 26           5    yeswomen小宜
# 27           4       Tikilee
# 28          34     FengFan_x
# 29          97      张思佳-SISI
# ..         ...           ...
# ...

# %%
df5_overlap.describe()
# Out:
#         celebrity  quchuhou_len
# count  102.000000    102.000000
# mean    53.441176      4.568627
# std     30.818078      3.901028
# min      0.000000      1.000000
# 25%     28.250000      1.000000
# 50%     53.500000      3.500000
# 75%     79.750000      6.000000
# max    107.000000     18.000000

# %%
df5_new.to_csv('ego_overlap_less.csv',index=False,encoding= 'utf8')
