# %%
import os
import sys
import pandas as pd
import csv 
import datetime
import time
import numpy as np

# %%
rootdir = 'C:/Users/Yee Shen/Desktop/source/interval_year/'
file_list = os.listdir(rootdir)


file_name = []
for i in range(0,len(file_list)):
    path = os.path.join(rootdir,file_list[i])
    if os.path.isfile(path):
        
        file_name.append(path)
        file_name = sorted(file_name)
file_name
# Out:
# ['C:/Users/Yee Shen/Desktop/source/interval_year/01.csv',
#  'C:/Users/Yee Shen/Desktop/source/interval_year/02.csv',
#  'C:/Users/Yee Shen/Desktop/source/interval_year/03.csv',
#  'C:/Users/Yee Shen/Desktop/source/interval_year/04.csv',
#  'C:/Users/Yee Shen/Desktop/source/interval_year/05.csv',
#  'C:/Users/Yee Shen/Desktop/source/interval_year/06.csv',
#  'C:/Users/Yee Shen/Desktop/source/interval_year/07.csv',
#  'C:/Users/Yee Shen/Desktop/source/interval_year/08.csv',
#  'C:/Users/Yee Shen/Desktop/source/interval_year/09.csv',
#  'C:/Users/Yee Shen/Desktop/source/interval_year/10.csv',
#  'C:/Users/Yee Shen/Desktop/source/interval_year/100.csv',
#  'C:/Users/Yee Shen/Desktop/source/interval_year/101.csv',
#  'C:/Users/Yee Shen/Desktop/source/interval_year/102.csv',
#  'C:/Users/Yee Shen/Desktop/source/interval_year/103.csv',
#  'C:/Users/Yee Shen/Desktop/source/interval_year/104.csv',
#  'C:/Users/Yee Shen/Desktop/source/interval_year/105.csv',
# ...

# %%
template = []
todel_name = file_name[10:19]
for delname in todel_name:
    template.append(file_name.pop(file_name.index(delname)))

file_name.extend(todel_name)
file_name
# Out:
# ['C:/Users/Yee Shen/Desktop/source/interval_year/01.csv',
#  'C:/Users/Yee Shen/Desktop/source/interval_year/02.csv',
#  'C:/Users/Yee Shen/Desktop/source/interval_year/03.csv',
#  'C:/Users/Yee Shen/Desktop/source/interval_year/04.csv',
#  'C:/Users/Yee Shen/Desktop/source/interval_year/05.csv',
#  'C:/Users/Yee Shen/Desktop/source/interval_year/06.csv',
#  'C:/Users/Yee Shen/Desktop/source/interval_year/07.csv',
#  'C:/Users/Yee Shen/Desktop/source/interval_year/08.csv',
#  'C:/Users/Yee Shen/Desktop/source/interval_year/09.csv',
#  'C:/Users/Yee Shen/Desktop/source/interval_year/10.csv',
#  'C:/Users/Yee Shen/Desktop/source/interval_year/11.csv',
#  'C:/Users/Yee Shen/Desktop/source/interval_year/12.csv',
#  'C:/Users/Yee Shen/Desktop/source/interval_year/13.csv',
#  'C:/Users/Yee Shen/Desktop/source/interval_year/14.csv',
#  'C:/Users/Yee Shen/Desktop/source/interval_year/15.csv',
#  'C:/Users/Yee Shen/Desktop/source/interval_year/16.csv',
# ...

# %%
test = pd.read_csv(file_name[0])
test.head()
# Out:
#    interval_ave    year
# 0     29.571429  2011.0
# 1     23.000000  2012.0
# 2     21.066667  2013.0
# 3     22.538462  2014.0
# 4     28.222222  2015.0

# %%
start = test['year'][0]
start
# Out:
# 2011.0

# %%
result = pd.DataFrame({'userid':[],'start':[]})
for i in range(len(file_name)):
    data = pd.read_csv(file_name[i])
    start = data['year'][0]
    tmp = pd.DataFrame({'userid':[i+1],'start':[start]})
    result = pd.concat([result,tmp],axis=0)

result
# Out:
#      start  userid
# 0   2011.0     1.0
# 0   2011.0     2.0
# 0   2013.0     3.0
# 0   2011.0     4.0
# 0   2010.0     5.0
# 0   2011.0     6.0
# 0   2014.0     7.0
# 0   2011.0     8.0
# 0   2011.0     9.0
# 0   2014.0    10.0
# 0   2014.0    11.0
# 0   2013.0    12.0
# 0   2014.0    13.0
# 0   2012.0    14.0
# 0   2013.0    15.0
# 0   2013.0    16.0
# 0   2011.0    17.0
# 0   2011.0    18.0
# 0   2011.0    19.0
# 0   2011.0    20.0
# 0   2014.0    21.0
# 0   2011.0    22.0
# 0   2014.0    23.0
# 0   2014.0    24.0
# 0   2013.0    25.0
# 0   2014.0    26.0
# 0   2013.0    27.0
# 0   2014.0    28.0
# 0   2015.0    29.0
# 0   2016.0    30.0
# ..     ...     ...
# 0   2011.0    79.0
# 0   2015.0    80.0
# 0   2012.0    81.0
# 0   2011.0    82.0
# 0   2015.0    83.0
# 0   2011.0    84.0
# 0   2014.0    85.0
# 0   2015.0    86.0
# 0   2010.0    87.0
# 0   2015.0    88.0
# 0   2017.0    89.0
# 0   2010.0    90.0
# 0   2015.0    91.0
# 0   2010.0    92.0
# 0   2011.0    93.0
# ...

# %%
data2 = pd.read_csv('cele_kmeans3_new.csv')
data2
# Out:
#      userid         0         1         2         3         4         5  \
# 0         1  0.182510  0.123203  0.086705  0.094595  0.135747  0.094733
# 1         2  0.207224  0.125257  0.127168  0.108108  0.149321  0.115195
# 2         3  0.183935  0.180698  0.213873  0.216216  0.303167  0.111785
# 3         4  0.406844  0.365503  0.300578  0.459459  0.334842  0.309587
# 4         5  0.309886  0.299795  0.341040  0.324324  0.176471  0.229254
# 5         6  0.062738  0.234086  0.109827  0.256757  0.149321  0.057598
# 6         7  0.490494  0.318275  0.364162  0.445946  0.217195  0.333081
# 7         8  0.258555  0.240246  0.173410  0.364865  0.226244  0.177719
# 8         9  0.233840  0.166324  0.236994  0.202703  0.149321  0.200834
# 9        10  0.084125  0.034908  0.028902  0.040541  0.058824  0.032967
# 10       11  0.043726  0.026694  0.005780  0.000000  0.009050  0.020083
# 11       12  0.465304  0.289528  0.289017  0.351351  0.266968  0.288746
# ...

# %%
data3 = data2[['userid','lable']]
data3
# Out:
#      userid  lable
# 0         1      2
# 1         2      2
# 2         3      2
# 3         4      0
# 4         5      2
# 5         6      1
# 6         7      0
# 7         8      2
# 8         9      2
# 9        10      1
# 10       11      1
# 11       12      0
# 12       13      2
# 13       14      2
# 14       15      2
# 15       16      2
# 16       17      2
# 17       18      0
# 18       19      1
# 19       20      0
# 20       21      2
# 21       22      1
# 22       23      1
# 23       24      1
# 24       25      1
# 25       26      1
# 26       27      1
# 27       28      1
# 28       29      1
# 29       30      1
# ..      ...    ...
# 78       79      0
# 79       80      1
# 80       81      1
# 81       82      2
# 82       83      2
# 83       84      2
# 84       85      2
# 85       86      1
# 86       87      2
# 87       88      2
# 88       89      1
# 89       90      0
# 90       91      2
# 91       92      1
# 92       93      1
# ...

# %%
data4 = pd.merge(result,data3,on = 'userid',how='inner')
data4
# Out:
#       start  userid  lable
# 0    2011.0     1.0      2
# 1    2011.0     2.0      2
# 2    2013.0     3.0      2
# 3    2011.0     4.0      0
# 4    2010.0     5.0      2
# 5    2011.0     6.0      1
# 6    2014.0     7.0      0
# 7    2011.0     8.0      2
# 8    2011.0     9.0      2
# 9    2014.0    10.0      1
# 10   2014.0    11.0      1
# 11   2013.0    12.0      0
# 12   2014.0    13.0      2
# 13   2012.0    14.0      2
# 14   2013.0    15.0      2
# 15   2013.0    16.0      2
# 16   2011.0    17.0      2
# 17   2011.0    18.0      0
# 18   2011.0    19.0      1
# 19   2011.0    20.0      0
# 20   2014.0    21.0      2
# 21   2011.0    22.0      1
# 22   2014.0    23.0      1
# 23   2014.0    24.0      1
# 24   2013.0    25.0      1
# 25   2014.0    26.0      1
# 26   2013.0    27.0      1
# 27   2014.0    28.0      1
# 28   2015.0    29.0      1
# 29   2016.0    30.0      1
# ..      ...     ...    ...
# 78   2011.0    79.0      0
# 79   2015.0    80.0      1
# ...

# %%
data5 = data4.sort_values('lable', axis=0, ascending=True)  
data5
# Out:
#       start  userid  lable
# 78   2011.0    79.0      0
# 34   2014.0    35.0      0
# 63   2014.0    64.0      0
# 68   2010.0    69.0      0
# 74   2014.0    75.0      0
# 19   2011.0    20.0      0
# 17   2011.0    18.0      0
# 89   2010.0    90.0      0
# 11   2013.0    12.0      0
# 44   2011.0    45.0      0
# 105  2013.0   106.0      0
# 6    2014.0     7.0      0
# 3    2011.0     4.0      0
# 94   2012.0    95.0      1
# 104  2013.0   105.0      1
# 62   2013.0    63.0      1
# 61   2011.0    62.0      1
# 60   2014.0    61.0      1
# 59   2015.0    60.0      1
# 58   2013.0    59.0      1
# 55   2014.0    56.0      1
# 54   2015.0    55.0      1
# 52   2016.0    53.0      1
# 48   2012.0    49.0      1
# 47   2011.0    48.0      1
# 56   2011.0    57.0      1
# 69   2015.0    70.0      1
# 71   2016.0    72.0      1
# 72   2012.0    73.0      1
# 99   2014.0   100.0      1
# ..      ...     ...    ...
# 2    2013.0     3.0      2
# 4    2010.0     5.0      2
# ...

# %%
data5.to_csv('new_start.csv', index = 0)

# %%
data6 = pd.read_csv('start_y.csv', encoding='utf_8_sig')
data6.head()
# Out:
#    start_y  userid
# 0   2010.0     1.0
# 1   2010.0     2.0
# 2   2013.0     3.0
# 3   2011.0     4.0
# 4   2010.0     5.0

# %%
final = pd.merge(data5,data6,on = 'userid',how='inner')
final
# Out:
#       start  userid  lable  start_y
# 0    2011.0    79.0      0   2009.0
# 1    2014.0    35.0      0   2011.0
# 2    2014.0    64.0      0   2010.0
# 3    2010.0    69.0      0   2010.0
# 4    2014.0    75.0      0   2011.0
# 5    2011.0    20.0      0   2010.0
# 6    2011.0    18.0      0   2010.0
# 7    2010.0    90.0      0   2010.0
# 8    2013.0    12.0      0   2011.0
# 9    2011.0    45.0      0   2011.0
# 10   2013.0   106.0      0   2010.0
# 11   2014.0     7.0      0   2012.0
# 12   2011.0     4.0      0   2011.0
# 13   2012.0    95.0      1   2011.0
# 14   2013.0   105.0      1   2010.0
# 15   2013.0    63.0      1   2012.0
# 16   2011.0    62.0      1   2010.0
# 17   2014.0    61.0      1   2011.0
# 18   2015.0    60.0      1   2015.0
# 19   2013.0    59.0      1   2011.0
# 20   2014.0    56.0      1   2012.0
# 21   2015.0    55.0      1   2013.0
# 22   2016.0    53.0      1   2011.0
# 23   2012.0    49.0      1   2010.0
# 24   2011.0    48.0      1   2010.0
# ...

# %%
final.to_csv('new_start.csv', index = 0)
