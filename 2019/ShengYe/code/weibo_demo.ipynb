# %%
#-*- coding:utf-8 -*-
import pandas  as pd
  
#读csv文件  
data = pd.read_csv('C:/Users/Yee Shen/Desktop/cleandata/01.csv',encoding='utf8')  
first_rows = data.head(n=5)
last_rows = data.tail(n=10)


print (last_rows)
# Out:
#        ﻿user             time        source  \
# 4847  ALU_U   2010/4/30 13:31  微博 weibo.com
# 4848  ALU_U   2010/4/14 13:26  微博 weibo.com
# 4849  ALU_U   2010/4/14 13:24  微博 weibo.com
# 4850  ALU_U   2010/4/14 13:23  微博 weibo.com
# 4851  ALU_U   2010/4/14 13:22  微博 weibo.com
# 4852  ALU_U   2010/4/14 13:21  微博 weibo.com
# 4853  ALU_U   2010/4/14 13:18  微博 weibo.com
# 4854  ALU_U   2010/4/14 13:16  微博 weibo.com
# 4855  ALU_U   2010/4/14 13:15  微博 weibo.com
# 4856  ALU_U   2010/4/14 10:43  微博 weibo.com
#
#                                                    text  repost  comment  \
# 4847                                    我真的笑不出了- - ​​​​       0       12
# 4848  很少说承诺 一旦说出就会履行 很少说“我爱你”，  说了出来就是真的爱你  喜欢用行动来证明...       2        1
# 4849  天蝎座吃醋时不爱说话 也不会明讲 只是你会发现天蝎座有点气嘟嘟的一个人生闷气 说话语气有点阴...       3        3
# 4850  也很少有人能让天蝎座情绪失控，  如果有就是看的很重的事或人。  失控时间不会很久，  短些...       2        2
# 4851  天蝎座不喜欢向别人提要求  对朋友一点要求都不会提。  如果向你提要求 就代表对你的喜欢和信...       3        2
# ...

# %%
import pandas as pd
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers:
#
# ...

# %%
dimensision = data.shape
print (dimensision)
# Out:
# (4857, 13)

# %%
dimensision
# Out:
# (4857, 13)

# %%
tmp = data[data['text'].isnull()]
result = tmp[tmp['re_user'].notnull()]
result.shape
# Out:
# (1343, 13)

# %%
len(result)
# Out:
# 1343

# %%
data.shape
# Out:
# (4857, 13)

# %%
# Out:
# Empty DataFrame
# Columns: [﻿user, time, source, text, repost, comment, like, re_user, re_time, re_text, re_repost, re_comment, re_like]
# Index: []

# %%
data['text'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4        True
# 5        True
# 6        True
# 7       False
# 8        True
# 9        True
# 10       True
# 11       True
# 12       True
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27       True
# 28      False
# 29      False
#         ...
# 4827    False
# 4828    False
# 4829    False
# 4830    False
# 4831    False
# 4832    False
# 4833    False
# 4834    False
# 4835    False
# 4836    False
# 4837    False
# 4838    False
# 4839    False
# 4840    False
# 4841    False
# 4842    False
# 4843    False
# 4844    False
# 4845    False
# 4846    False
# 4847    False
# 4848    False
# 4849    False
# 4850    False
# 4851    False
# 4852    False
# 4853    False
# 4854    False
# 4855    False
# 4856    False
# Name: text, dtype: bool

# %%
tmp2 = data[data['text'].notnull()]
result2 = tmp2[tmp2['re_user'].notnull()]
result2.shape
# Out:
# (679, 13)

# %%
result2
# Out:
#        ﻿user              time          source  \
# 0      ALU_U    2018/4/4 22:19      👶🏻iPhone X
# 1      ALU_U    2018/4/4 22:18      👶🏻iPhone X
# 2      ALU_U    2018/4/4 22:17      👶🏻iPhone X
# 7      ALU_U    2018/3/31 8:43      👶🏻iPhone X
# 52     ALU_U   2018/3/16 23:18      👶🏻iPhone X
# 54     ALU_U   2018/3/16 10:32      👶🏻iPhone X
# 55     ALU_U   2018/3/14 12:10      👶🏻iPhone X
# 56     ALU_U   2018/3/14 10:06      👶🏻iPhone X
# 57     ALU_U   2018/3/14 10:05      👶🏻iPhone X
# 59     ALU_U   2018/3/11 19:17        iPhone X
# 60     ALU_U   2018/3/11 16:03        iPhone X
# 86     ALU_U     2018/3/1 7:47        iPhone X
# 88     ALU_U   2018/2/28 12:45        iPhone X
# 89     ALU_U    2018/2/28 7:26        iPhone X
# 90     ALU_U    2018/2/28 7:25        iPhone X
# 91     ALU_U   2018/2/27 10:28   iPhone 7 Plus
# 93     ALU_U   2018/2/27 10:24   iPhone 7 Plus
# 96     ALU_U   2018/2/26 11:50   iPhone 7 Plus
# 98     ALU_U   2018/2/22 19:31   iPhone 7 Plus
# ...

# %%
tmp3 = data[data['text'].notnull()]
result3 = tmp3[tmp3['re_user'].isnull()]
result3.shape
# Out:
# (2834, 13)

# %%
help(result2.drop)
# Out:
# Help on method drop in module pandas.core.generic:
#
# drop(labels, axis=0, level=None, inplace=False, errors='raise') method of pandas.core.frame.DataFrame instance
#     Return new object with labels in requested axis removed
#
#     Parameters
#     ----------
#     labels : single label or list-like
#     axis : int or axis name
#     level : int or level name, default None
#         For MultiIndex
#     inplace : bool, default False
#         If True, do operation inplace and return None.
#     errors : {'ignore', 'raise'}, default 'raise'
#         If 'ignore', suppress error and existing labels are dropped.
#
#         .. versionadded:: 0.16.1
#
#     Returns
#     -------
#     dropped : type of caller

# %%
result2.drop([60],inplace=True)
# Out:
# D:\Professional software\Anaconda3\lib\site-packages\IPython\kernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
import os 

rootdir = 'C:/Users/Yee Shen/Desktop/cleandata'
list = os.listdir(rootdir)

# %%
list
# Out:
# ['01.csv',
#  '02.csv',
#  '03.csv',
#  '04..csv',
#  '05.csv',
#  '06.csv',
#  '07.csv',
#  '08.csv',
#  '09.csv',
#  '10.csv',
#  '100.csv',
#  '101.csv',
#  '102.csv',
#  '103.csv',
#  '104.csv',
#  '105.csv',
#  '106.csv',
#  '107.csv',
#  '108.csv',
#  '11.csv',
#  '12.csv',
#  '13.csv',
#  '14.csv',
#  '15.csv',
#  '16.csv',
#  '17.csv',
#  '18.csv',
#  '19.csv',
#  '20.csv',
#  '21.csv',
#  '22.csv',
#  '23.csv',
#  '24.csv',
#  '25.csv',
#  '26.csv',
#  '27.csv',
#  '28.csv',
#  '29.csv',
#  '30.csv',
#  '31.csv',
#  '32.csv',
#  '33.csv',
#  '34.csv',
#  '35.csv',
#  '36.csv',
#  '37.csv',
#  '38.csv',
#  '39.csv',
#  '40.csv',
#  '41.csv',
#  '42.csv',
#  '43.csv',
#  '44.csv',
#  '45.csv',
#  '46.csv',
#  '47.csv',
#  '48.csv',
#  '49.csv',
#  '50.csv',
#  '51.csv',
#  '52.csv',
#  '53.csv',
#  '54.csv',
#  '55.csv',
#  '56.csv',
#  '57.csv',
#  '58.csv',
#  '59.csv',
#  '60.csv',
#  '61.csv',
#  '62.csv',
#  '63.csv',
#  '64.csv',
#  '65.csv',
#  '66.csv',
#  '67.csv',
# ...

# %%
for i in range(0,len(list)):
       path = os.path.join(rootdir,list[i])
       if os.path.isfile(path):
