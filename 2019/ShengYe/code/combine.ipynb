# %%
import os
import sys
import pandas as pd
import csv

# %%
data1 = pd.read_excel('C:/Users/Yee Shen/Desktop/淘宝店铺信息url.xlsx')
data2 = pd.read_excel('C:/Users/Yee Shen/Desktop/淘宝店铺销量.xlsx')

# %%
data1
# Out:
#       id                                taobao_url  \
# 0      1        https://alu13.taobao.com/index.htm
# 1      2                https://lin828.taobao.com/
# 2      3       https://next-in-fashion.taobao.com/
# 3      4            https://mtastudios.taobao.com/
# 4      5               https://tkstyle.taobao.com/
# 5      6          https://yeswomen2010.taobao.com/
# 6      7            https://zystudiozy.taobao.com/
# 7      8          https://vcruanruanvc.taobao.com/
# 8      9           https://langlangyes.taobao.com/
# 9     10            https://superman33.taobao.com/
# 10    11                 https://tm-tm.taobao.com/
# 11    12              https://h-xiaxia.taobao.com/
# 12    13                https://zowzow.taobao.com/
# 13    14           https://zhaoyandaxi.taobao.com/
# 14    15                  https://iwes.taobao.com/
# 15    16              https://room-209.taobao.com/
# 16    17              https://yumomolk.taobao.com/
# ...

# %%
data2
# Out:
#                                              info_url   credit refund_rate  \
# 0   https://rate.taobao.com/user-rate-UvC84Omx0MC8...   893935      80.28%
# 1   https://rate.taobao.com/user-rate-UMFcyvCNbMm8...  2475574      53.37%
# 2   https://rate.taobao.com/user-rate-UMFkWvmg4OFH...   826952      54.51%
# 3   https://rate.taobao.com/user-rate-UMGgYvCvYvGN...   796183      44.99%
# 4   https://rate.taobao.com/user-rate-UvFNSOm8SMCg...  2288782      32.28%
# 5   https://rate.taobao.com/user-rate-UvFxuMGg4MGH...  4169378      40.92%
# 6   https://rate.taobao.com/user-rate-UvFk4MFg4MGN...   945335      38.92%
# 7   https://rate.taobao.com/user-rate-UvCxSvFxSMmc...  1635805      40.72%
# 8   https://rate.taobao.com/user-rate-UMFgYvm8LvCQ...  1278608      82.07%
# 9   https://rate.taobao.com/user-rate-UvFvYvmcuvCv...  2317829      37.97%
# 10  https://rate.taobao.com/user-rate-UMFxbMmkuvCx...  1641674      48.98%
# ...

# %%
df = pd.merge(data1,data2,how='left')

# %%
df
# Out:
#       id                                taobao_url  \
# 0      1        https://alu13.taobao.com/index.htm
# 1      1        https://alu13.taobao.com/index.htm
# 2      2                https://lin828.taobao.com/
# 3      2                https://lin828.taobao.com/
# 4      3       https://next-in-fashion.taobao.com/
# 5      3       https://next-in-fashion.taobao.com/
# 6      4            https://mtastudios.taobao.com/
# 7      4            https://mtastudios.taobao.com/
# 8      5               https://tkstyle.taobao.com/
# 9      5               https://tkstyle.taobao.com/
# 10     6          https://yeswomen2010.taobao.com/
# 11     6          https://yeswomen2010.taobao.com/
# 12     7            https://zystudiozy.taobao.com/
# 13     7            https://zystudiozy.taobao.com/
# 14     8          https://vcruanruanvc.taobao.com/
# 15     8          https://vcruanruanvc.taobao.com/
# 16     9           https://langlangyes.taobao.com/
# ...

# %%
df.to_excel('taobao_info.xlsx')

# %%
data3 = pd.read_excel('C:/Users/Yee Shen/Desktop/source/taobao_info.xlsx')
data4 = pd.read_excel('C:/Users/Yee Shen/Desktop/淘宝店铺销量6.15.xlsx')

# %%
data3
# Out:
#       id                           taobao_url  \
# 0      1   https://alu13.taobao.com/index.htm
# 1      2           https://lin828.taobao.com/
# 2      3  https://next-in-fashion.taobao.com/
# 3      4       https://mtastudios.taobao.com/
# 4      5          https://tkstyle.taobao.com/
# 5      6     https://yeswomen2010.taobao.com/
# 6      7       https://zystudiozy.taobao.com/
# 7      8     https://vcruanruanvc.taobao.com/
# 8      9      https://langlangyes.taobao.com/
# 9     10       https://superman33.taobao.com/
# 10    11            https://tm-tm.taobao.com/
# 11    12         https://h-xiaxia.taobao.com/
# 12    13           https://zowzow.taobao.com/
# 13    14      https://zhaoyandaxi.taobao.com/
# 14    15             https://iwes.taobao.com/
# 15    16         https://room-209.taobao.com/
# 16    17         https://yumomolk.taobao.com/
# 17    18          https://bigeve8.taobao.com/
# 18    19          https://love13c.taobao.com/
# ...

# %%
data4
# Out:
#                                              info_url    credit refund_rate  \
# 0   https://rate.taobao.com/user-rate-UvCNyvCNuMCQ...   1037757      32.84%
# 1   https://rate.taobao.com/user-rate-UvFguMFkLMGH...    295666      45.10%
# 2   https://rate.taobao.com/user-rate-UvGNWOF8YMCc...     39693      17.74%
# 3   https://rate.taobao.com/user-rate-UMGH0MCNbMmH...  11257324      36.86%
# 4   https://rate.taobao.com/user-rate-UvFxYMmxbOm8...    231068      11.87%
# 5   https://rate.taobao.com/user-rate-UMCx0MmcWMmg...    118920      31.35%
# 6   https://rate.taobao.com/user-rate-UvFN0OFISOmx...    758776      27.36%
# 7   https://rate.taobao.com/user-rate-UMmI0OmxYOmc...     38086       0.00%
# 8   https://rate.taobao.com/user-rate-UvFg0vCNbvCN...    368611      75.75%
# 9   https://rate.taobao.com/user-rate-UOmvLMFNLvF8...      9456      28.96%
# 10  https://rate.taobao.com/user-rate-UvFvLMCH0MCv...    878887      94.36%
# ...
