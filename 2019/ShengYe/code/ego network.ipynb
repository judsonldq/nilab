# %%
import os
import sys
import math
import numpy as np
import pandas as pd
import csv 
import matplotlib.pyplot as plt

# %%
rootdir = 'C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/'
file_list = os.listdir(rootdir)


file_name = []
for i in range(0,len(file_list)):
    path = os.path.join(rootdir,file_list[i])
    if os.path.isfile(path):
        
        file_name.append(path)
        file_name = sorted(file_name)

# %%
file_name
# Out:
# ['C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/00.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/01.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/02.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/03.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/04.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/05.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/06.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/07.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/08.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/09.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/10.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/100.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/101.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/102.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/103.csv',
# ...

# %%
file_name.index('C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/100.csv')
# Out:
# 11

# %%
file_name.index('C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/107.csv')
# Out:
# 18

# %%
template = []
todel_name = file_name[11:19]
for delname in todel_name:
    template.append(file_name.pop(file_name.index(delname)))

# %%
template
# Out:
# ['C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/100.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/101.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/102.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/103.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/104.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/105.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/106.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/107.csv']

# %%
file_name
# Out:
# ['C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/00.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/01.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/02.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/03.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/04.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/05.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/06.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/07.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/08.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/09.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/10.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/11.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/12.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/13.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/14.csv',
# ...

# %%
file_name.extend(todel_name)

# %%
file_name
# Out:
# ['C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/00.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/01.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/02.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/03.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/04.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/05.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/06.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/07.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/08.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/09.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/10.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/11.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/12.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/13.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_repo&like/14.csv',
# ...

# %%
test = pd.read_csv(file_name[0])

# %%
test
# Out:
#       ﻿﻿user              time        source  \
# 0      ALU_U    4/4/2018 22:19    👶🏻iPhone X
# 1      ALU_U    4/4/2018 22:18    👶🏻iPhone X
# 2      ALU_U    4/4/2018 22:17    👶🏻iPhone X
# 3      ALU_U    4/3/2018 15:00           NaN
# 4      ALU_U    4/2/2018 11:25           NaN
# 5      ALU_U    4/1/2018 16:05           NaN
# 6      ALU_U     4/1/2018 8:29           NaN
# 7      ALU_U    3/31/2018 8:43    👶🏻iPhone X
# 8      ALU_U   3/30/2018 15:14           NaN
# 9      ALU_U    3/30/2018 0:05           NaN
# 10     ALU_U   3/29/2018 15:47           NaN
# 11     ALU_U    3/28/2018 9:36           NaN
# 12     ALU_U   3/27/2018 16:01           NaN
# 13     ALU_U   3/24/2018 14:32           NaN
# 14     ALU_U   3/23/2018 23:57           NaN
# 15     ALU_U    3/23/2018 9:01           NaN
# 16     ALU_U   3/22/2018 23:43           NaN
# 17     ALU_U   3/22/2018 17:59           NaN
# 18     ALU_U   3/22/2018 16:21           NaN
# 19     ALU_U    3/21/2018 1:20           NaN
# ...

# %%
size = test.groupby('re_user').size()

# %%
alter = pd.DataFrame(size,columns = ['contact'])

# %%
alter
# Out:
#                       contact
# re_user
# --Kimci-                    1
# -3-圆园圆园子                    1
# -CCW-                       2
# -Fashionbaby                6
# -__LuaLu__-                 1
# -___Candice___-             8
# -九尾狐小姐                      1
# -土豆坨坨                       1
# -阿sa哥                       1
# -首长                         1
# 1m_SorRy_1_ReAlLY_Am        1
# 2erM                        1
# 8090穿衣搭配学堂                  1
# 8KATy                       1
# ALUONLINESHOP             207
# ALU_U                     846
# AMY_U_1011                  1
# ANNIEJIA_                   1
# AOBBLY                      1
# AW-W                        1
# AWY絻絻                       1
# Ai_LiLi2018                 1
# Amelie小鸟                    1
# Angelvi                     1
# Anny__Fan                   2
# Annyz_z                     1
# BMW敏                        2
# BabeeQueenCindy             1
# BabyYu_uU                   1
# ...

# %%
alter.columns
# Out:
# Index(['contact'], dtype='object')

# %%
alter.reset_index()
# Out:
#                   re_user  contact
# 0                --Kimci-        1
# 1                -3-圆园圆园子        1
# 2                   -CCW-        2
# 3            -Fashionbaby        6
# 4             -__LuaLu__-        1
# 5         -___Candice___-        8
# 6                  -九尾狐小姐        1
# 7                   -土豆坨坨        1
# 8                   -阿sa哥        1
# 9                     -首长        1
# 10   1m_SorRy_1_ReAlLY_Am        1
# 11                   2erM        1
# 12             8090穿衣搭配学堂        1
# 13                  8KATy        1
# 14          ALUONLINESHOP      207
# 15                  ALU_U      846
# 16             AMY_U_1011        1
# 17              ANNIEJIA_        1
# 18                 AOBBLY        1
# 19                   AW-W        1
# 20                  AWY絻絻        1
# 21            Ai_LiLi2018        1
# 22               Amelie小鸟        1
# 23                Angelvi        1
# 24              Anny__Fan        2
# 25                Annyz_z        1
# ...

# %%
alter.to_csv(str(i)+'.csv', encoding='utf_8_sig')

# %%
for i in range(len(file_name)):
    temp = pd.read_csv(file_name[i])
    size = temp.groupby('re_user').size()
    alter = pd.DataFrame(size,columns = ['contact'])
    alter.reset_index()
    alter.to_csv(str(i)+'.csv', encoding='utf_8_sig')

# %%
rootdir = 'C:/Users/Yee Shen/Desktop/source/cleandata_alter/'
file_list = os.listdir(rootdir)


file_name = []
for i in range(0,len(file_list)):
    path = os.path.join(rootdir,file_list[i])
    if os.path.isfile(path):
        
        file_name.append(path)
        file_name = sorted(file_name)

template = []
todel_name = file_name[11:19]
for delname in todel_name:
    template.append(file_name.pop(file_name.index(delname)))
    
file_name.extend(todel_name)
file_name
# Out:
# ['C:/Users/Yee Shen/Desktop/source/cleandata_alter/00.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_alter/01.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_alter/02.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_alter/03.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_alter/04.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_alter/05.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_alter/06.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_alter/07.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_alter/08.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_alter/09.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_alter/10.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_alter/11.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_alter/12.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_alter/13.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_alter/14.csv',
#  'C:/Users/Yee Shen/Desktop/source/cleandata_alter/15.csv',
# ...

# %%
test1 = pd.read_csv(file_name[0])
test1
# Out:
#                  ﻿re_user  contact
# 0                --Kimci-        1
# 1                -3-圆园圆园子        1
# 2                   -CCW-        2
# 3            -Fashionbaby        6
# 4             -__LuaLu__-        1
# 5         -___Candice___-        8
# 6                  -九尾狐小姐        1
# 7                   -土豆坨坨        1
# 8                   -阿sa哥        1
# 9                     -首长        1
# 10   1m_SorRy_1_ReAlLY_Am        1
# 11                   2erM        1
# 12             8090穿衣搭配学堂        1
# 13                  8KATy        1
# 14          ALUONLINESHOP      207
# 15                  ALU_U      846
# 16             AMY_U_1011        1
# 17              ANNIEJIA_        1
# 18                 AOBBLY        1
# 19                   AW-W        1
# 20                  AWY絻絻        1
# 21            Ai_LiLi2018        1
# 22               Amelie小鸟        1
# 23                Angelvi        1
# 24              Anny__Fan        2
# 25                Annyz_z        1
# ...

# %%
test1['userid']=0
test1
# Out:
#                  ﻿re_user  contact  userid
# 0                --Kimci-        1       0
# 1                -3-圆园圆园子        1       0
# 2                   -CCW-        2       0
# 3            -Fashionbaby        6       0
# 4             -__LuaLu__-        1       0
# 5         -___Candice___-        8       0
# 6                  -九尾狐小姐        1       0
# 7                   -土豆坨坨        1       0
# 8                   -阿sa哥        1       0
# 9                     -首长        1       0
# 10   1m_SorRy_1_ReAlLY_Am        1       0
# 11                   2erM        1       0
# 12             8090穿衣搭配学堂        1       0
# 13                  8KATy        1       0
# 14          ALUONLINESHOP      207       0
# 15                  ALU_U      846       0
# 16             AMY_U_1011        1       0
# 17              ANNIEJIA_        1       0
# 18                 AOBBLY        1       0
# 19                   AW-W        1       0
# 20                  AWY絻絻        1       0
# ...

# %%
num = len(test1)
num
# Out:
# 594

# %%
en_size = pd.DataFrame({'userid':[],'alter_num':[]})
for i in range(len(file_name)):
    tmp = pd.read_csv(file_name[i])
    num = len(tmp)
    result = pd.DataFrame({'userid':[i+1],'alter_num':[num]})
    en_size = pd.concat([en_size,result],axis=0)

en_size
# Out:
#     alter_num  userid
# 0         594       1
# 0         700       2
# 0         737       3
# 0        1592       4
# 0        1158       5
# 0         420       6
# 0        1735       7
# 0         977       8
# 0         814       9
# 0         268      10
# 0         134      11
# 0        1609      12
# 0         644      13
# 0        1102      14
# 0         469      15
# 0         742      16
# 0        1019      17
# 0        3089      18
# 0         246      19
# 0        1882      20
# 0         777      21
# 0         432      22
# 0         247      23
# 0         467      24
# 0         494      25
# 0         297      26
# 0          36      27
# 0         318      28
# 0         214      29
# 0         157      30
# ..        ...     ...
# 0        2623      78
# 0          72      79
# 0         351      80
# 0         568      81
# 0         595      82
# 0         849      83
# 0         766      84
# 0          32      85
# 0         823      86
# ...

# %%
x = range(1,109)
y = en_size['alter_num'].tolist()

plt.xlabel('online celebrities')  
plt.ylabel('network size')  
plt.bar(x,y)
plt.xlim(1,109)
plt.show()

# %%
en_size.describe()
# Out:
#          alter_num     userid
# count   108.000000  108.00000
# mean    698.583333   54.50000
# std     671.852915   31.32092
# min       1.000000    1.00000
# 25%     246.750000   27.75000
# 50%     448.500000   54.50000
# 75%     935.750000   81.25000
# max    3406.000000  108.00000

# %%
alter_overlap = pd.DataFrame({'userid':[],'contact':[]})
for i in range(len(file_name)):
    tmp = pd.read_csv(file_name[i])
    tmp['userid'] = i
    alter_overlap = pd.concat([alter_overlap,tmp],axis=0)

alter_overlap
# Out:
#      contact  userid              ﻿re_user
# 0          1       0              --Kimci-
# 1          1       0              -3-圆园圆园子
# 2          2       0                 -CCW-
# 3          6       0          -Fashionbaby
# 4          1       0           -__LuaLu__-
# 5          8       0       -___Candice___-
# 6          1       0                -九尾狐小姐
# 7          1       0                 -土豆坨坨
# 8          1       0                 -阿sa哥
# 9          1       0                   -首长
# 10         1       0  1m_SorRy_1_ReAlLY_Am
# 11         1       0                  2erM
# 12         1       0            8090穿衣搭配学堂
# 13         1       0                 8KATy
# 14       207       0         ALUONLINESHOP
# 15       846       0                 ALU_U
# 16         1       0            AMY_U_1011
# 17         1       0             ANNIEJIA_
# 18         1       0                AOBBLY
# 19         1       0                  AW-W
# 20         1       0                 AWY絻絻
# ...

# %%
alter_overlap.columns
# Out:
# Index(['contact', 'userid', '﻿re_user'], dtype='object')

# %%
alter_overlap.to_csv('alter_overlap.csv',index=False, encoding='utf_8_sig')

# %% [markdown]
# # Debug

# %%
alter_overlap.to_csv('alter_overlap_debug.csv', encoding='utf8',index=False)

# %%
len(tmp)
# Out:
# 325

# %%
df = pd.read_csv('alter_overlap_debug.csv', encoding='utf8')
df
# Out:
#        contact  userid              ﻿re_user
# 0          1.0     0.0              --Kimci-
# 1          1.0     0.0              -3-圆园圆园子
# 2          2.0     0.0                 -CCW-
# 3          6.0     0.0          -Fashionbaby
# 4          1.0     0.0           -__LuaLu__-
# 5          8.0     0.0       -___Candice___-
# 6          1.0     0.0                -九尾狐小姐
# 7          1.0     0.0                 -土豆坨坨
# 8          1.0     0.0                 -阿sa哥
# 9          1.0     0.0                   -首长
# 10         1.0     0.0  1m_SorRy_1_ReAlLY_Am
# 11         1.0     0.0                  2erM
# 12         1.0     0.0            8090穿衣搭配学堂
# 13         1.0     0.0                 8KATy
# 14       207.0     0.0         ALUONLINESHOP
# 15       846.0     0.0                 ALU_U
# 16         1.0     0.0            AMY_U_1011
# 17         1.0     0.0             ANNIEJIA_
# 18         1.0     0.0                AOBBLY
# 19         1.0     0.0                  AW-W
# ...

# %%
df.columns
# Out:
# Index(['contact', 'userid', '﻿re_user'], dtype='object')

# %%
df.groupby(['﻿re_user'],as_index=False).count()
# Out:
#                ﻿re_user  contact  userid
# 0                #NAME?        1       1
# 1      ----------傲娇的小胖纸        1       1
# 2              ------杨丽        1       1
# 3             -----C---        1       1
# 4         -----丸子------        1       1
# 5                -----孋        1       1
# 6              -----思思思        1       1
# 7            ----CocoLu        1       1
# 8              ----Demi        1       1
# 9           ----P-P----        1       1
# 10              ----周君羊        1       1
# 11          ----小璇子----        1       1
# 12           ---Lola---        1       1
# 13           ---ZhuDanT        1       1
# 14           ---biang--        1       1
# 15               ---six        1       1
# 16            ---史迪仔---        2       2
# 17       ---小仙女--------        1       1
# 18            ---王可欣---        1       1
# 19            ---白兔糖---        1       1
# 20                 ---薰        1       1
# 21               ---阿阿杰        1       1
# ...
