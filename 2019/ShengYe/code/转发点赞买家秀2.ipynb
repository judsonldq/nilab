# %%
import os
import sys
import pandas as pd
import csv 
import datetime
import time
import numpy as np

# %%
rootdir = 'C:/Users/Yee Shen/Desktop/source/repo&like_fanslv/'
file_list = os.listdir(rootdir)


file_name = []
for i in range(0,len(file_list)):
    path = os.path.join(rootdir,file_list[i])
    if os.path.isfile(path):
        
        file_name.append(path)
        file_name = sorted(file_name)

template = []
todel_name = file_name[10:19]
for delname in todel_name:
    template.append(file_name.pop(file_name.index(delname)))

file_name.extend(todel_name)
file_name
# Out:
# ['C:/Users/Yee Shen/Desktop/source/repo&like_fanslv/01.csv',
#  'C:/Users/Yee Shen/Desktop/source/repo&like_fanslv/02.csv',
#  'C:/Users/Yee Shen/Desktop/source/repo&like_fanslv/03.csv',
#  'C:/Users/Yee Shen/Desktop/source/repo&like_fanslv/04.csv',
#  'C:/Users/Yee Shen/Desktop/source/repo&like_fanslv/05.csv',
#  'C:/Users/Yee Shen/Desktop/source/repo&like_fanslv/06.csv',
#  'C:/Users/Yee Shen/Desktop/source/repo&like_fanslv/07.csv',
#  'C:/Users/Yee Shen/Desktop/source/repo&like_fanslv/08.csv',
#  'C:/Users/Yee Shen/Desktop/source/repo&like_fanslv/09.csv',
#  'C:/Users/Yee Shen/Desktop/source/repo&like_fanslv/10.csv',
#  'C:/Users/Yee Shen/Desktop/source/repo&like_fanslv/11.csv',
#  'C:/Users/Yee Shen/Desktop/source/repo&like_fanslv/12.csv',
#  'C:/Users/Yee Shen/Desktop/source/repo&like_fanslv/13.csv',
#  'C:/Users/Yee Shen/Desktop/source/repo&like_fanslv/14.csv',
#  'C:/Users/Yee Shen/Desktop/source/repo&like_fanslv/15.csv',
# ...

# %%
file_name[29]
# Out:
# 'C:/Users/Yee Shen/Desktop/source/repo&like_fanslv/31.csv'

# %%
test = pd.read_csv(file_name[0])
test.head()
# Out:
#    fanslv_1  fanslv_2  fanslv_3  fanslv_4  fanslv_5  year
# 0         0         0         0         0         2  2010
# 1         2         2         7         3        25  2011
# 2         6         8        18         2         5  2012
# 3        13         4        29         2        17  2013
# 4        20        26        41         0        30  2014

# %%
sum1 = sum(test['fanslv_1'])
sum1
# Out:
# 332

# %%
result = pd.DataFrame({'id':[],'perc':[]})
for i in range(len(file_name)):
        test = pd.read_csv(file_name[i])
        sum1 = sum(test['fanslv_1'])
        sum2 = sum(test['fanslv_2'])
        sum3 = sum(test['fanslv_3'])
        sum4 = sum(test['fanslv_4'])
        sum5 = sum(test['fanslv_5'])
        
        perc = (sum1 + sum2 + sum3) / (sum1 + sum2 + sum3 + sum4 + sum5)
        tmp = pd.DataFrame({'id':[i+1],'perc':[perc]})
        result = pd.concat([result,tmp],axis=0)
        
result
# Out:
#        id      perc
# 0     1.0  0.750736
# 0     2.0  0.751076
# 0     3.0  0.774301
# 0     4.0  0.931338
# 0     5.0  0.922247
# 0     6.0  0.955645
# 0     7.0  0.863158
# 0     8.0  0.962304
# 0     9.0  0.902965
# 0    10.0  0.591549
# 0    11.0  0.906475
# 0    12.0  0.758604
# 0    13.0  0.525350
# 0    14.0  0.855645
# 0    15.0  0.895652
# 0    16.0  0.775647
# 0    17.0  0.840419
# 0    18.0  0.663836
# 0    19.0  0.929515
# 0    20.0  0.952306
# 0    21.0  0.967882
# 0    22.0  0.522659
# 0    23.0  0.862745
# 0    24.0  0.889984
# 0    25.0  0.944238
# 0    26.0  0.521368
# 0    27.0  0.520000
# 0    28.0  0.891419
# 0    29.0  0.753571
# 0    30.0  0.654545
# ..    ...       ...
# 0    78.0  0.825683
# 0    79.0  0.981848
# 0    80.0  0.530637
# 0    81.0  0.802691
# 0    82.0  0.516773
# 0    83.0  0.655970
# 0    84.0  0.649123
# 0    85.0  0.923077
# 0    86.0  0.781044
# 0    87.0  0.808773
# 0    88.0  0.948187
# 0    89.0  0.959727
# 0    90.0  0.788724
# ...

# %%
result.describe()
# Out:
#                id        perc
# count  107.000000  107.000000
# mean    54.000000    0.763631
# std     31.032241    0.174107
# min      1.000000    0.285714
# 25%     27.500000    0.636181
# 50%     54.000000    0.802120
# 75%     80.500000    0.905963
# max    107.000000    0.982095
