# %%
import pandas as pd

# %%
data = pd.read_excel("alters信息.xlsx")

# %%
data.to_csv('data.csv',encoding='utf-8')

# %%
data['detail'][0]
# Out:
# "-Gabrieltutu-\n            \n                        +关注\n                    \n        \n                        \n                        天津 塘沽区\n            个人主页\n        \n                \n            关注616\n            粉丝1888\n            微博237\n        \n        简介：👼🏻🌸If you can't live longer,live deeper🌸👼🏻\n        \n        教育信息：紫云中学育才中学天津师范大学津沽学院"

# %%
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-12-1fac93ad11be> in <module>()
#       1 #encoding 'GBK'
#       2 with open("alters信息.xlsx",encoding='GBK') as f:
# ----> 3     for line in f.readlines():
#       4         line = line.strip()
#       5         print(line)
#
# UnicodeDecodeError: 'gbk' codec can't decode byte 0xa2 in position 46: illegal multibyte sequence

# %%
new_data = pd.read_csv("data.csv")

# %%
data_list = new_data['detail'].tolist()

# %%
ele0 =data_list[0].split('\n')

# %%
result = []
for ele in ele0:
      # 三个元素，分别对应 关注、粉丝、和微博数量。
    ele = ele.strip()
    
    if ele.startswith("关注"):
        result.append(ele)
    if ele.startswith("粉丝"):
        result.append(ele)
    if ele.startswith("微博"):
        result.append(ele)
    
    print(ele)
# Out:
# -Gabrieltutu-
#
# +关注
#
#
#
# 天津 塘沽区
# 个人主页
#
#
# 关注616
# 粉丝1888
# 微博237
#
# 简介：👼🏻🌸If you can't live longer,live deeper🌸👼🏻
#
# 教育信息：紫云中学育才中学天津师范大学津沽学院

# %%
result
# Out:
# ['关注616', '粉丝1888', '微博237']

# %%
import pandas as pd 
data = pd.read_csv("data.csv",encoding='utf-8')
data_list = data['detail'].tolist()

result = []
for element in data_list:
    tmp = []
    line_data = element.strip().split('\n')
    tmp.append(line_data[0])
    for ele in line_data:
        ele = ele.strip()
        if ele.startswith('关注') or ele.startswith('粉丝') or ele.startswith('微博'):
            tmp.append(ele)
    result.append(tmp)

    
data['result'] = result

# %%
data
# Out:
#       Unnamed: 0                                             detail  \
# 0              0  -Gabrieltutu-\n            \n                 ...
# 1              1  Aaaa大米l\n            \n                       ...
# 2              2  fearless_3_\n            \n                   ...
# 3              3  Miky_su\n            \n                       ...
# 4              4  橘studio\n            \n                       ...
# 5              5  YT新媒体\n            \n                        +...
# 6              6  番茄炒蛋菇凉\n            \n                        ...
# 7              7  徐yoyoyo\n            \n                       ...
# 8              8  SSS-pan\n            \n                       ...
# 9              9  cutecute小cj\n            \n                   ...
# 10            10  YJNaNaNaJH\n            \n                    ...
# 11            11  上海嘉定\n            \n                        +关...
# 12            12  李大白\n            \n                        +关注...
# 13            13  -甜甜o\n            \n                        +关...
# 14            14  伊尔夫咖啡屋\n            \n                        ...
# 15            15  -田心思-\n            \n                        +...
# 16            16  lovesukida\n            \n                    ...
# 17            17  奋壹\n            \n                        +关注\...
# 18            18  GAlANO涵曦\n            \n                      ...
# 19            19  柠檬树和柠檬叶\n            \n                       ...
# 20            20  -南陌吖-\n            \n                        +...
# 21            21  牛逼轰轰带闪电的梅XX\n            \n                   ...
# 22            22  陈祉霏Stephanie\n            \n                  ...
# 23            23  戚小雯\n            \n                        +关注...
